# %%
import os
import torch
import numpy as np
import tensorflow as tf
from io import BytesIO
from PIL import Image
from tensorflow.keras.models import load_model
from flask import Flask, request, jsonify, send_file, Response
from database import save_data_to_database, get_image_data
from subprocess_code import prepro_image, synthesis_image
from inference import Predictor, CELEBRITY_LABELS, ANIMAL_LABELS
from zipfile import ZipFile
from beauty_supplies import search_supplies

app = Flask(__name__)

# 모델폴더
model_folder = "./PredictModels"

# 이미지 전처리 함수
def preprocess_image(img_path):
    img = Image.open(img_path)
    img = img.resize((192, 192))
    img = img.convert("RGB")
    img = np.asarray(img)
    img = img.astype('float32') / 255
    return img

# 모델을 사용한 이미지 분류 함수
def predict_image_with_models(image_path, model_folder):
    categories = np.array(["0", "1", "2", "3"])
    scalp_category = ["미세각질", "피지과다", "모낭사이홍반", "모낭홍반/농포", "비듬", "탈모"]

    model_files = [f for f in os.listdir(model_folder) if f.endswith(".h5")]
    print(model_files)
    alter_predict = []

    predict1 = []
    predict2 = []
    predict3 = []
    predict4 = []
    predict5 = []
    predict6 = []
    image = Image.open(image_path)

    with tf.device("/device:CPU:0"):
        for i, model_file in enumerate(model_files):
            print(os.getcwd())
            print(model_file)
            model_path = model_folder + '/' + model_file
            print(model_path)
            model = load_model(model_path)
            test = []
            test.append(preprocess_image(image_path))
            test = np.array(test)

            
            predict = model.predict(test)
            predicted_class_index = predict[0]
            
            # Print class probabilities
            print(f"Probabilities for model {model_file} ({scalp_category[i]}):")
            for class_index, probability in enumerate(predicted_class_index):
                print(f'Class {class_index}: {probability * 100}%')
                [predict1, predict2, predict3, predict4, predict5, predict6][i].append(round(probability * 100, 2))
                
            print([predict1, predict2, predict3, predict4, predict5, predict6][i])
            predicted_class_index = np.argmax(predicted_class_index)
            predicted_category = categories[predicted_class_index]

            print(f"모델 파일: {model_file}")
            print("예측된 카테고리(" +  scalp_category[i] +  "): " +  predicted_category + "\n")

            alter_predict.append(predicted_category)

    print("alter_predict: ", alter_predict, "\n")
    
    # 피부진단 결과 계산
    skin_diagnosis = calculate_skin_diagnosis(alter_predict)

    return skin_diagnosis, alter_predict, predict1, predict2, predict3, predict4, predict5, predict6

def calculate_skin_diagnosis(alter_predict):
    # 여기서부터 피부진단 시작
    # 양호: 배열 안에 값이 전부 0인 경우
    if all(category == '0' for category in alter_predict):
        return "양호"

    # 건성: 배열 첫 번째 값은 3이고, 배열 두 번째 값은 1~3, 배열 5번째 값은 1~3 나머지는 3이 아님
    if (
        alter_predict[0] == '3' and
        (1 <= int(alter_predict[1]) <= 3) and
        (1 <= int(alter_predict[4]) <= 3) and
        all(category != '3' for category in alter_predict[2:4]) and
        all(category != '3' for category in alter_predict[5:])
    ):
        return "건성"

    # 지성: 배열 두 번째 값이 3이고 나머지 값이 3이 아닌 경우
    if (
        (1 <= int(alter_predict[1]) <= 3) and
        all(category != '3' for category in alter_predict[2:])
    ):
        return "지성"

    # 민감성: 배열 세 번째 값이 3이고 나머지 값이 3이 아닌 경우
    if (
        (0 <= int(alter_predict[0]) <= 3) and
        alter_predict[2] == '3' and
        all(category != '3' for category in alter_predict[3:])
    ):
        return "민감성"

    # 지루성: 배열 첫 번째 값이 3이고 다섯 번째, 여섯 번째 값이 2~3이고 나머지가 3이 아닌 경우
    if (
        alter_predict[0] == '3' and
        (2 <= int(alter_predict[4]) <= 3) and
        (2 <= int(alter_predict[5]) <= 3) and
        all(category != '3' for category in alter_predict[1:4])
    ):
        return "지루성"

    # 염증성: 배열 네 번째 값이 3이고 세 번째 값이 2~3이면서 나머지가 3이 아닌 경우
    if (
        alter_predict[2] == '3' and
        alter_predict[3] == '3'
    ):
        return "염증성"

    # 비듬성: 배열 2, 5번째 값이 2~3이고 나머지 배열 값이 3이 아닌 경우
    if (
        alter_predict[0] == '3' and
        (2 <= int(alter_predict[1]) <= 3) and
        (2 <= int(alter_predict[2]) <= 3) and
        (2 <= int(alter_predict[3]) <= 3) and
        (2 <= int(alter_predict[4]) <= 3) and
        alter_predict[5] != '3'
    ):
        return "비듬성"

    # 탈모: 배열 6번째 값이 3이고 나머지 배열 값이 3이 아닌 경우
    if (
        alter_predict[5] == '3' and
        all(category != '3' for category in alter_predict[:5])
    ):
        return "탈모"

    # 기타: 위 조건에 해당하지 않는 경우
    return "복합성"

@app.route('/upload', methods=['POST'])
def upload_image():
    if 'image' not in request.files:
        return jsonify({'error': 'No image part'})

    file = request.files['image']
    userid = request.form['userid']

    if file.filename == '':
        return jsonify({'error': 'No selected file'})

    if file:
        # 이미지를 저장할 경로를 지정합니다.
        upload_dir = './skin_upload'
        if not os.path.exists(upload_dir):
            os.makedirs(upload_dir)
        file_path = os.path.join(upload_dir, file.filename)
        file.save(file_path)

        # 이미지 분석 및 진단 결과 얻기
        diagnosis_result, alter_predict, predict1, predict2, predict3, predict4, predict5, predict6 = predict_image_with_models(file_path, model_folder)
        print(diagnosis_result)
        print(*alter_predict)
        predict1_str = ','.join(map(str, [int(round(x)) for x in predict1]))
        predict2_str = ','.join(map(str, [int(round(x)) for x in predict2]))
        predict3_str = ','.join(map(str, [int(round(x)) for x in predict3]))
        predict4_str = ','.join(map(str, [int(round(x)) for x in predict4]))
        predict5_str = ','.join(map(str, [int(round(x)) for x in predict5]))
        predict6_str = ','.join(map(str, [int(round(x)) for x in predict6]))

        print(predict1_str)
        print(predict2_str)
        print(predict3_str)
        print(predict4_str)
        print(predict5_str)
        print(predict6_str)
        # 진단 결과와 alter_predict를 함께 JSON 응답으로 반환
        response_data = {'message': diagnosis_result,'predict1': predict1_str, 
                        'predict2': predict2_str, 'predict3': predict3_str,
                        'predict4': predict4_str, 'predict5': predict5_str,
                        'predict6': predict6_str }
        
        # 데이터베이스에 데이터 저장
        save_data_to_database(file_path, diagnosis_result, alter_predict, userid)

        print("Mysql 전송 완료")
        
        return jsonify(response_data)
    
selected_wig = 0 # default

@app.route('/wear_wig', methods=['POST'])
def wear_wig():
    print(torch.cuda.is_available())
    os.environ["CUDA_VISIBLE_DEVICES"]="0"
    # 이미지 파일 받기
    image = request.files['image']
    # 선택된 가발 값 받기
    selected_wig = int(request.form['selectedWig'])

    source_path = './unprocessed/source.jpg'
    image.save(source_path)  # 이미지를 지정된 경로에 저장
        
    # 이곳에서 이미지 처리 및 가발 적용 로직을 구현
    script_path = "align_face.py"
        
    result1 = prepro_image(script_path)
    print(result1)
        
    label = 'male'

    ref_path = './images/ref/target' + str(selected_wig+1) + '.png'
    src = Image.open('./images/src/source.png').convert("RGB")
    ref = Image.open(ref_path).convert("RGB")

    entity = "celebrity"

    predictor = Predictor(entity=entity)
    predictor.create_interpolation(label, src_image=src, ref_image=ref)
        
    synthesis_output = "./images/res.jpg"
    
    # 이미지 처리 완료 후, PNG 이미지를 열고 JPG로 변환
    with Image.open(synthesis_output) as img:
        img = img.convert('RGB')
        jpg_output = synthesis_output.replace(".png", ".jpg")
        img.save(jpg_output, "JPEG")

    jpg_path = "./images/res.jpg"
    # JPG 파일을 클라이언트로 전송
    return send_file(jpg_path, mimetype='image/jpeg')


# 이미지 파일들을 압축하여 클라이언트에게 보내는 엔드포인트
@app.route('/progress_status', methods=['GET'])
def progress_status():
    try:
        user_id = request.args.get('userId')
        zip_file_path = get_image_data(user_id)
        
        print(zip_file_path)
        download_name = os.path.basename(zip_file_path)
        print(download_name)
        # 클라이언트에게 압축 파일을 전송
        response = send_file(zip_file_path, as_attachment=False, download_name=download_name, mimetype='application/zip')
        
        return response
    except Exception as e:
        return str(e)
    
@app.route('/beauty_supplies', methods=['GET'])
def start_crawl():
    symptom = request.args.get('symptom')
    print("받은 증상: " + symptom)
    search_supplies(symptom)
    return send_file('./supplies_result.txt', as_attachment=True, mimetype='text/plain')
    
if __name__ == '__main__':
    app.run(host='192.168.43.168', port=5000, debug=False, use_reloader=False, threaded=True)
# Out:
# c:\jupyter\capston\bald\hairskinWig
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://192.168.43.168:5000
# Press CTRL+C to quit
# 받은 증상: 양호
# ['양호']
# {}
# 받은 증상: 양호
# ['양호']
# {}
# 192.168.43.1 - - [26/Nov/2023 19:50:24] "GET /beauty_supplies?symptom=양호 HTTP/1.1" 200 -
# 192.168.43.1 - - [26/Nov/2023 19:50:26] "GET /beauty_supplies?symptom=양호 HTTP/1.1" 200 -
# Image 1 added to the ZIP archive
# Image 2 added to the ZIP archive
# Image 3 added to the ZIP archive
# Image 4 added to the ZIP archive
# Image 5 added to the ZIP archive
# Image 6 added to the ZIP archive
# Image 7 added to the ZIP archive
# Image 8 added to the ZIP archive
# Image 9 added to the ZIP archive
# Image 10 added to the ZIP archive
# Image 11 added to the ZIP archive
# Image 12 added to the ZIP archive
# Image 13 added to the ZIP archive
# Image 14 added to the ZIP archive
# Image 15 added to the ZIP archive
# Image 16 added to the ZIP archive
# Image 17 added to the ZIP archive
# Image 18 added to the ZIP archive
# Image 19 added to the ZIP archive
# Image 20 added to the ZIP archive
# Image 21 added to the ZIP archive
# Image 22 added to the ZIP archive
# Image 23 added to the ZIP archive
# Image 24 added to the ZIP archive
# Image 25 added to the ZIP archive
# Image 26 added to the ZIP archive
# Image 27 added to the ZIP archive
# Image 28 added to the ZIP archive
# Image 29 added to the ZIP archive
# Image 30 added to the ZIP archive
# Image 31 added to the ZIP archive
# Image 32 added to the ZIP archive
# Image 33 added to the ZIP archive
# Image 34 added to the ZIP archive
# Image 35 added to the ZIP archive
# Image 36 added to the ZIP archive
# Image 37 added to the ZIP archive
# Image 38 added to the ZIP archive
# Image 39 added to the ZIP archive
# Image 40 added to the ZIP archive
# Image 41 added to the ZIP archive
# Image 42 added to the ZIP archive
# Image 43 added to the ZIP archive
# Image 44 added to the ZIP archive
# Image 45 added to the ZIP archive
# Image 46 added to the ZIP archive
# Image 47 added to the ZIP archive
# Image 48 added to the ZIP archive
# Image 49 added to the ZIP archive
# Image 50 added to the ZIP archive
# Image 51 added to the ZIP archive
# Image 52 added to the ZIP archive
# Image 53 added to the ZIP archive
# Image 54 added to the ZIP archive
# Image 55 added to the ZIP archive
# Image 56 added to the ZIP archive
# Image 57 added to the ZIP archive
# Image 58 added to the ZIP archive
# Image 59 added to the ZIP archive
# Image 60 added to the ZIP archive
# Image 61 added to the ZIP archive
# Image 62 added to the ZIP archive
# Image 63 added to the ZIP archive
# Image 64 added to the ZIP archive
# Image 65 added to the ZIP archive
# Image 66 added to the ZIP archive
# Image 67 added to the ZIP archive
# Image 68 added to the ZIP archive
# Image 69 added to the ZIP archive
# Image 70 added to the ZIP archive
# Image 71 added to the ZIP archive
# Image 72 added to the ZIP archive
# Image 73 added to the ZIP archive
# Image 74 added to the ZIP archive
# Image 75 added to the ZIP archive
# Image 76 added to the ZIP archive
# ZIP file saved to ./get_analysis_data/image_data.zip
# ./get_analysis_data/image_data.zip
# image_data.zip
# 192.168.43.1 - - [26/Nov/2023 19:55:24] "GET /progress_status?userId=mingky0603 HTTP/1.1" 200 -
# ['1_Corneous_Xception_1.h5', '2_Sebum_Xception_1.h5', '3_ErFo_Xception_1.h5', '4_Fep_Xception_1.h5', '5_Dandruff_Xception_1.h5', '6_Hairloss_Xception_1.h5']
# c:\jupyter\capston\bald\hairskinWig
# 1_Corneous_Xception_1.h5
# ./PredictModels/1_Corneous_Xception_1.h5
# Probabilities for model 1_Corneous_Xception_1.h5 (미세각질):
# Class 0: 100.0%
# Class 1: 4.391116092961056e-06%
# Class 2: 1.4030264580341956e-11%
# Class 3: 1.4670717765619123e-09%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 1_Corneous_Xception_1.h5
# 예측된 카테고리(미세각질): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 2_Sebum_Xception_1.h5
# ./PredictModels/2_Sebum_Xception_1.h5
# Probabilities for model 2_Sebum_Xception_1.h5 (피지과다):
# Class 0: 100.0%
# Class 1: 7.062554967934842e-10%
# Class 2: 1.1140417032612631e-12%
# Class 3: 5.643739065127199e-17%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 2_Sebum_Xception_1.h5
# 예측된 카테고리(피지과다): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 3_ErFo_Xception_1.h5
# ./PredictModels/3_ErFo_Xception_1.h5
# Probabilities for model 3_ErFo_Xception_1.h5 (모낭사이홍반):
# Class 0: 100.0%
# Class 1: 2.9720529422933017e-12%
# Class 2: 5.377967278482407e-16%
# Class 3: 1.243695333490279e-19%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 3_ErFo_Xception_1.h5
# 예측된 카테고리(모낭사이홍반): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 4_Fep_Xception_1.h5
# ./PredictModels/4_Fep_Xception_1.h5
# Probabilities for model 4_Fep_Xception_1.h5 (모낭홍반/농포):
# Class 0: 100.0%
# Class 1: 3.7978225165408164e-11%
# Class 2: 1.0680448204932816e-14%
# Class 3: 5.360033807587632e-13%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 4_Fep_Xception_1.h5
# 예측된 카테고리(모낭홍반/농포): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 5_Dandruff_Xception_1.h5
# ./PredictModels/5_Dandruff_Xception_1.h5
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B7CAD243A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Probabilities for model 5_Dandruff_Xception_1.h5 (비듬):
# Class 0: 100.0%
# Class 1: 1.2393447560559235e-16%
# Class 2: 7.424815364487217e-16%
# Class 3: 7.105781314802558e-17%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 5_Dandruff_Xception_1.h5
# 예측된 카테고리(비듬): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 6_Hairloss_Xception_1.h5
# ./PredictModels/6_Hairloss_Xception_1.h5
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B7C42CFD30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Probabilities for model 6_Hairloss_Xception_1.h5 (탈모):
# Class 0: 100.0%
# Class 1: 9.42545755506512e-16%
# Class 2: 2.717595481982471e-07%
# Class 3: 3.9671892370772915e-16%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 6_Hairloss_Xception_1.h5
# 예측된 카테고리(탈모): 0
#
# alter_predict:  ['0', '0', '0', '0', '0', '0']
#
# 양호
# 0 0 0 0 0 0
# 100,0,0,0
# 100,0,0,0
# 100,0,0,0
# 100,0,0,0
# 100,0,0,0
# 100,0,0,0
# Mysql 전송 완료
# 192.168.43.1 - - [26/Nov/2023 20:17:14] "POST /upload HTTP/1.1" 200 -
# 받은 증상: 양호
# ['양호']
# {}
# 받은 증상: 양호
# ['양호']
# {}
# 192.168.43.1 - - [26/Nov/2023 20:17:36] "GET /beauty_supplies?symptom=양호 HTTP/1.1" 200 -
# 192.168.43.1 - - [26/Nov/2023 20:17:37] "GET /beauty_supplies?symptom=양호 HTTP/1.1" 200 -
# Image 1 added to the ZIP archive
# Image 2 added to the ZIP archive
# Image 3 added to the ZIP archive
# Image 4 added to the ZIP archive
# Image 5 added to the ZIP archive
# Image 6 added to the ZIP archive
# Image 7 added to the ZIP archive
# Image 8 added to the ZIP archive
# Image 9 added to the ZIP archive
# Image 10 added to the ZIP archive
# Image 11 added to the ZIP archive
# Image 12 added to the ZIP archive
# Image 13 added to the ZIP archive
# Image 14 added to the ZIP archive
# Image 15 added to the ZIP archive
# Image 16 added to the ZIP archive
# Image 17 added to the ZIP archive
# Image 18 added to the ZIP archive
# Image 19 added to the ZIP archive
# Image 20 added to the ZIP archive
# Image 21 added to the ZIP archive
# Image 22 added to the ZIP archive
# Image 23 added to the ZIP archive
# Image 24 added to the ZIP archive
# Image 25 added to the ZIP archive
# Image 26 added to the ZIP archive
# Image 27 added to the ZIP archive
# Image 28 added to the ZIP archive
# Image 29 added to the ZIP archive
# Image 30 added to the ZIP archive
# Image 31 added to the ZIP archive
# Image 32 added to the ZIP archive
# Image 33 added to the ZIP archive
# Image 34 added to the ZIP archive
# Image 35 added to the ZIP archive
# Image 36 added to the ZIP archive
# Image 37 added to the ZIP archive
# Image 38 added to the ZIP archive
# Image 39 added to the ZIP archive
# Image 40 added to the ZIP archive
# Image 41 added to the ZIP archive
# Image 42 added to the ZIP archive
# Image 43 added to the ZIP archive
# Image 44 added to the ZIP archive
# Image 45 added to the ZIP archive
# Image 46 added to the ZIP archive
# Image 47 added to the ZIP archive
# Image 48 added to the ZIP archive
# Image 49 added to the ZIP archive
# Image 50 added to the ZIP archive
# Image 51 added to the ZIP archive
# Image 52 added to the ZIP archive
# Image 53 added to the ZIP archive
# Image 54 added to the ZIP archive
# Image 55 added to the ZIP archive
# Image 56 added to the ZIP archive
# Image 57 added to the ZIP archive
# Image 58 added to the ZIP archive
# Image 59 added to the ZIP archive
# Image 60 added to the ZIP archive
# Image 61 added to the ZIP archive
# Image 62 added to the ZIP archive
# Image 63 added to the ZIP archive
# Image 64 added to the ZIP archive
# Image 65 added to the ZIP archive
# Image 66 added to the ZIP archive
# Image 67 added to the ZIP archive
# Image 68 added to the ZIP archive
# Image 69 added to the ZIP archive
# Image 70 added to the ZIP archive
# Image 71 added to the ZIP archive
# Image 72 added to the ZIP archive
# Image 73 added to the ZIP archive
# Image 74 added to the ZIP archive
# Image 75 added to the ZIP archive
# Image 76 added to the ZIP archive
# Image 77 added to the ZIP archive
# ZIP file saved to ./get_analysis_data/image_data.zip
# ./get_analysis_data/image_data.zip
# image_data.zip
# 192.168.43.1 - - [26/Nov/2023 20:19:20] "GET /progress_status?userId=mingky0603 HTTP/1.1" 200 -
# ['1_Corneous_Xception_1.h5', '2_Sebum_Xception_1.h5', '3_ErFo_Xception_1.h5', '4_Fep_Xception_1.h5', '5_Dandruff_Xception_1.h5', '6_Hairloss_Xception_1.h5']
# c:\jupyter\capston\bald\hairskinWig
# 1_Corneous_Xception_1.h5
# ./PredictModels/1_Corneous_Xception_1.h5
# Probabilities for model 1_Corneous_Xception_1.h5 (미세각질):
# Class 0: 100.0%
# Class 1: 3.187492804423986e-10%
# Class 2: 2.1311044550452777e-15%
# Class 3: 3.2311810308139526e-13%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 1_Corneous_Xception_1.h5
# 예측된 카테고리(미세각질): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 2_Sebum_Xception_1.h5
# ./PredictModels/2_Sebum_Xception_1.h5
# Probabilities for model 2_Sebum_Xception_1.h5 (피지과다):
# Class 0: 100.0%
# Class 1: 4.9406594706563435e-15%
# Class 2: 1.238268888696452e-21%
# Class 3: 3.0057654682717745e-21%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 2_Sebum_Xception_1.h5
# 예측된 카테고리(피지과다): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 3_ErFo_Xception_1.h5
# ./PredictModels/3_ErFo_Xception_1.h5
# Probabilities for model 3_ErFo_Xception_1.h5 (모낭사이홍반):
# Class 0: 100.0%
# Class 1: 2.499596124701242e-11%
# Class 2: 1.0228672462253997e-13%
# Class 3: 1.5626206086012692e-15%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 3_ErFo_Xception_1.h5
# 예측된 카테고리(모낭사이홍반): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 4_Fep_Xception_1.h5
# ./PredictModels/4_Fep_Xception_1.h5
# Probabilities for model 4_Fep_Xception_1.h5 (모낭홍반/농포):
# Class 0: 100.0%
# Class 1: 2.5591817854351345e-17%
# Class 2: 4.721138722820387e-16%
# Class 3: 2.8490021423298928e-16%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 4_Fep_Xception_1.h5
# 예측된 카테고리(모낭홍반/농포): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 5_Dandruff_Xception_1.h5
# ./PredictModels/5_Dandruff_Xception_1.h5
# Probabilities for model 5_Dandruff_Xception_1.h5 (비듬):
# Class 0: 100.0%
# Class 1: 1.190884483267081e-16%
# Class 2: 7.640536949421398e-25%
# Class 3: 7.538085488248566e-24%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 5_Dandruff_Xception_1.h5
# 예측된 카테고리(비듬): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 6_Hairloss_Xception_1.h5
# ./PredictModels/6_Hairloss_Xception_1.h5
# Probabilities for model 6_Hairloss_Xception_1.h5 (탈모):
# Class 0: 99.99992847442627%
# Class 1: 4.9557471841488177e-11%
# Class 2: 6.667798970738659e-05%
# Class 3: 3.452687302729629e-08%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 6_Hairloss_Xception_1.h5
# 예측된 카테고리(탈모): 0
#
# alter_predict:  ['0', '0', '0', '0', '0', '0']
#
# 양호
# 0 0 0 0 0 0
# 100,0,0,0
# 100,0,0,0
# 100,0,0,0
# 100,0,0,0
# 100,0,0,0
# 100,0,0,0
# Mysql 전송 완료
# 192.168.43.1 - - [26/Nov/2023 20:22:39] "POST /upload HTTP/1.1" 200 -
# 받은 증상: 양호
# ['양호']
# {}
# 받은 증상: 양호
# ['양호']
# {}
# 192.168.43.1 - - [26/Nov/2023 20:23:01] "GET /beauty_supplies?symptom=양호 HTTP/1.1" 200 -
# 192.168.43.1 - - [26/Nov/2023 20:23:01] "GET /beauty_supplies?symptom=양호 HTTP/1.1" 200 -
# Image 1 added to the ZIP archive
# Image 2 added to the ZIP archive
# Image 3 added to the ZIP archive
# Image 4 added to the ZIP archive
# Image 5 added to the ZIP archive
# Image 6 added to the ZIP archive
# Image 7 added to the ZIP archive
# Image 8 added to the ZIP archive
# Image 9 added to the ZIP archive
# Image 10 added to the ZIP archive
# Image 11 added to the ZIP archive
# Image 12 added to the ZIP archive
# Image 13 added to the ZIP archive
# Image 14 added to the ZIP archive
# Image 15 added to the ZIP archive
# Image 16 added to the ZIP archive
# Image 17 added to the ZIP archive
# Image 18 added to the ZIP archive
# Image 19 added to the ZIP archive
# Image 20 added to the ZIP archive
# Image 21 added to the ZIP archive
# Image 22 added to the ZIP archive
# Image 23 added to the ZIP archive
# Image 24 added to the ZIP archive
# Image 25 added to the ZIP archive
# Image 26 added to the ZIP archive
# Image 27 added to the ZIP archive
# Image 28 added to the ZIP archive
# Image 29 added to the ZIP archive
# Image 30 added to the ZIP archive
# Image 31 added to the ZIP archive
# Image 32 added to the ZIP archive
# Image 33 added to the ZIP archive
# Image 34 added to the ZIP archive
# Image 35 added to the ZIP archive
# Image 36 added to the ZIP archive
# Image 37 added to the ZIP archive
# Image 38 added to the ZIP archive
# Image 39 added to the ZIP archive
# Image 40 added to the ZIP archive
# Image 41 added to the ZIP archive
# Image 42 added to the ZIP archive
# Image 43 added to the ZIP archive
# Image 44 added to the ZIP archive
# Image 45 added to the ZIP archive
# Image 46 added to the ZIP archive
# Image 47 added to the ZIP archive
# Image 48 added to the ZIP archive
# Image 49 added to the ZIP archive
# Image 50 added to the ZIP archive
# Image 51 added to the ZIP archive
# Image 52 added to the ZIP archive
# Image 53 added to the ZIP archive
# Image 54 added to the ZIP archive
# Image 55 added to the ZIP archive
# Image 56 added to the ZIP archive
# Image 57 added to the ZIP archive
# Image 58 added to the ZIP archive
# Image 59 added to the ZIP archive
# Image 60 added to the ZIP archive
# Image 61 added to the ZIP archive
# Image 62 added to the ZIP archive
# Image 63 added to the ZIP archive
# Image 64 added to the ZIP archive
# Image 65 added to the ZIP archive
# Image 66 added to the ZIP archive
# Image 67 added to the ZIP archive
# Image 68 added to the ZIP archive
# Image 69 added to the ZIP archive
# Image 70 added to the ZIP archive
# Image 71 added to the ZIP archive
# Image 72 added to the ZIP archive
# Image 73 added to the ZIP archive
# Image 74 added to the ZIP archive
# Image 75 added to the ZIP archive
# Image 76 added to the ZIP archive
# Image 77 added to the ZIP archive
# Image 78 added to the ZIP archive
# ZIP file saved to ./get_analysis_data/image_data.zip
# ./get_analysis_data/image_data.zip
# image_data.zip
# 192.168.43.1 - - [26/Nov/2023 20:24:34] "GET /progress_status?userId=mingky0603 HTTP/1.1" 200 -
# ['1_Corneous_Xception_1.h5', '2_Sebum_Xception_1.h5', '3_ErFo_Xception_1.h5', '4_Fep_Xception_1.h5', '5_Dandruff_Xception_1.h5', '6_Hairloss_Xception_1.h5']
# c:\jupyter\capston\bald\hairskinWig
# 1_Corneous_Xception_1.h5
# ./PredictModels/1_Corneous_Xception_1.h5
# Probabilities for model 1_Corneous_Xception_1.h5 (미세각질):
# Class 0: 0.05025903810746968%
# Class 1: 0.5030648317188025%
# Class 2: 99.25320744514465%
# Class 3: 0.19346451153978705%
# [0.05, 0.5, 99.25, 0.19]
# 모델 파일: 1_Corneous_Xception_1.h5
# 예측된 카테고리(미세각질): 2
#
# c:\jupyter\capston\bald\hairskinWig
# 2_Sebum_Xception_1.h5
# ./PredictModels/2_Sebum_Xception_1.h5
# Probabilities for model 2_Sebum_Xception_1.h5 (피지과다):
# Class 0: 0.03309313324280083%
# Class 1: 0.7449744734913111%
# Class 2: 3.2555561512708664%
# Class 3: 95.96637487411499%
# [0.03, 0.74, 3.26, 95.97]
# 모델 파일: 2_Sebum_Xception_1.h5
# 예측된 카테고리(피지과다): 3
#
# c:\jupyter\capston\bald\hairskinWig
# 3_ErFo_Xception_1.h5
# ./PredictModels/3_ErFo_Xception_1.h5
# Probabilities for model 3_ErFo_Xception_1.h5 (모낭사이홍반):
# Class 0: 9.857514500617981%
# Class 1: 7.32114240527153%
# Class 2: 82.81688690185547%
# Class 3: 0.004449767948244698%
# [9.86, 7.32, 82.82, 0.0]
# 모델 파일: 3_ErFo_Xception_1.h5
# 예측된 카테고리(모낭사이홍반): 2
#
# c:\jupyter\capston\bald\hairskinWig
# 4_Fep_Xception_1.h5
# ./PredictModels/4_Fep_Xception_1.h5
# Probabilities for model 4_Fep_Xception_1.h5 (모낭홍반/농포):
# Class 0: 0.9965292178094387%
# Class 1: 25.582358241081238%
# Class 2: 72.32992053031921%
# Class 3: 1.0911975987255573%
# [1.0, 25.58, 72.33, 1.09]
# 모델 파일: 4_Fep_Xception_1.h5
# 예측된 카테고리(모낭홍반/농포): 2
#
# c:\jupyter\capston\bald\hairskinWig
# 5_Dandruff_Xception_1.h5
# ./PredictModels/5_Dandruff_Xception_1.h5
# Probabilities for model 5_Dandruff_Xception_1.h5 (비듬):
# Class 0: 16.363327205181122%
# Class 1: 83.63462686538696%
# Class 2: 0.0020208757632644847%
# Class 3: 3.342225625146966e-05%
# [16.36, 83.63, 0.0, 0.0]
# 모델 파일: 5_Dandruff_Xception_1.h5
# 예측된 카테고리(비듬): 1
#
# c:\jupyter\capston\bald\hairskinWig
# 6_Hairloss_Xception_1.h5
# ./PredictModels/6_Hairloss_Xception_1.h5
# Probabilities for model 6_Hairloss_Xception_1.h5 (탈모):
# Class 0: 0.10963297681882977%
# Class 1: 98.89785647392273%
# Class 2: 0.3824523650109768%
# Class 3: 0.6100635509938002%
# [0.11, 98.9, 0.38, 0.61]
# 모델 파일: 6_Hairloss_Xception_1.h5
# 예측된 카테고리(탈모): 1
#
# alter_predict:  ['2', '3', '2', '2', '1', '1']
#
# 지성
# 2 3 2 2 1 1
# 0,0,99,0
# 0,1,3,96
# 10,7,83,0
# 1,26,72,1
# 16,84,0,0
# 0,99,0,1
# Mysql 전송 완료
# 192.168.43.1 - - [26/Nov/2023 20:26:33] "POST /upload HTTP/1.1" 200 -
# ['1_Corneous_Xception_1.h5', '2_Sebum_Xception_1.h5', '3_ErFo_Xception_1.h5', '4_Fep_Xception_1.h5', '5_Dandruff_Xception_1.h5', '6_Hairloss_Xception_1.h5']
# c:\jupyter\capston\bald\hairskinWig
# 1_Corneous_Xception_1.h5
# ./PredictModels/1_Corneous_Xception_1.h5
# Probabilities for model 1_Corneous_Xception_1.h5 (미세각질):
# Class 0: 1.1845005336878018e-24%
# Class 1: 1.6243428588518612e-21%
# Class 2: 4.740863257524097e-09%
# Class 3: 100.0%
# [0.0, 0.0, 0.0, 100.0]
# 모델 파일: 1_Corneous_Xception_1.h5
# 예측된 카테고리(미세각질): 3
#
# c:\jupyter\capston\bald\hairskinWig
# 2_Sebum_Xception_1.h5
# ./PredictModels/2_Sebum_Xception_1.h5
# Probabilities for model 2_Sebum_Xception_1.h5 (피지과다):
# Class 0: 4.8143233200861735e-18%
# Class 1: 5.4209154526363434e-11%
# Class 2: 3.969551909399627e-08%
# Class 3: 100.0%
# [0.0, 0.0, 0.0, 100.0]
# 모델 파일: 2_Sebum_Xception_1.h5
# 예측된 카테고리(피지과다): 3
#
# c:\jupyter\capston\bald\hairskinWig
# 3_ErFo_Xception_1.h5
# ./PredictModels/3_ErFo_Xception_1.h5
# Probabilities for model 3_ErFo_Xception_1.h5 (모낭사이홍반):
# Class 0: 3.7016403831025e-08%
# Class 1: 1.4581915674938273e-07%
# Class 2: 0.023974309442564845%
# Class 3: 99.97602105140686%
# [0.0, 0.0, 0.02, 99.98]
# 모델 파일: 3_ErFo_Xception_1.h5
# 예측된 카테고리(모낭사이홍반): 3
#
# c:\jupyter\capston\bald\hairskinWig
# 4_Fep_Xception_1.h5
# ./PredictModels/4_Fep_Xception_1.h5
# Probabilities for model 4_Fep_Xception_1.h5 (모낭홍반/농포):
# Class 0: 1.661529834345258e-12%
# Class 1: 0.0058798188547370955%
# Class 2: 99.99411106109619%
# Class 3: 1.3184192937387706e-05%
# [0.0, 0.01, 99.99, 0.0]
# 모델 파일: 4_Fep_Xception_1.h5
# 예측된 카테고리(모낭홍반/농포): 2
#
# c:\jupyter\capston\bald\hairskinWig
# 5_Dandruff_Xception_1.h5
# ./PredictModels/5_Dandruff_Xception_1.h5
# Probabilities for model 5_Dandruff_Xception_1.h5 (비듬):
# Class 0: 6.592981377120232e-20%
# Class 1: 6.960684464955381e-19%
# Class 2: 9.189670725773258e-10%
# Class 3: 100.0%
# [0.0, 0.0, 0.0, 100.0]
# 모델 파일: 5_Dandruff_Xception_1.h5
# 예측된 카테고리(비듬): 3
#
# c:\jupyter\capston\bald\hairskinWig
# 6_Hairloss_Xception_1.h5
# ./PredictModels/6_Hairloss_Xception_1.h5
# Probabilities for model 6_Hairloss_Xception_1.h5 (탈모):
# Class 0: 0.0009362090167996939%
# Class 1: 90.96304178237915%
# Class 2: 8.52944403886795%
# Class 3: 0.5065873730927706%
# [0.0, 90.96, 8.53, 0.51]
# 모델 파일: 6_Hairloss_Xception_1.h5
# 예측된 카테고리(탈모): 1
#
# alter_predict:  ['3', '3', '3', '2', '3', '1']
#
# 비듬성
# 3 3 3 2 3 1
# 0,0,0,100
# 0,0,0,100
# 0,0,0,100
# 0,0,100,0
# 0,0,0,100
# 0,91,9,1
# Mysql 전송 완료
# 192.168.43.1 - - [26/Nov/2023 20:26:56] "POST /upload HTTP/1.1" 200 -
# ['1_Corneous_Xception_1.h5', '2_Sebum_Xception_1.h5', '3_ErFo_Xception_1.h5', '4_Fep_Xception_1.h5', '5_Dandruff_Xception_1.h5', '6_Hairloss_Xception_1.h5']
# c:\jupyter\capston\bald\hairskinWig
# 1_Corneous_Xception_1.h5
# ./PredictModels/1_Corneous_Xception_1.h5
# Probabilities for model 1_Corneous_Xception_1.h5 (미세각질):
# Class 0: 6.796553542187667e-07%
# Class 1: 0.000699076281307498%
# Class 2: 3.286705521077238e-05%
# Class 3: 99.99926090240479%
# [0.0, 0.0, 0.0, 100.0]
# 모델 파일: 1_Corneous_Xception_1.h5
# 예측된 카테고리(미세각질): 3
#
# c:\jupyter\capston\bald\hairskinWig
# 2_Sebum_Xception_1.h5
# ./PredictModels/2_Sebum_Xception_1.h5
# Probabilities for model 2_Sebum_Xception_1.h5 (피지과다):
# Class 0: 4.8187942525146354e-08%
# Class 1: 9.092522645914869e-06%
# Class 2: 1.077999733922752e-06%
# Class 3: 99.99998807907104%
# [0.0, 0.0, 0.0, 100.0]
# 모델 파일: 2_Sebum_Xception_1.h5
# 예측된 카테고리(피지과다): 3
#
# c:\jupyter\capston\bald\hairskinWig
# 3_ErFo_Xception_1.h5
# ./PredictModels/3_ErFo_Xception_1.h5
# Probabilities for model 3_ErFo_Xception_1.h5 (모낭사이홍반):
# Class 0: 0.018026142788585275%
# Class 1: 1.4749147929251194%
# Class 2: 2.264872193336487%
# Class 3: 96.24217748641968%
# [0.02, 1.47, 2.26, 96.24]
# 모델 파일: 3_ErFo_Xception_1.h5
# 예측된 카테고리(모낭사이홍반): 3
#
# c:\jupyter\capston\bald\hairskinWig
# 4_Fep_Xception_1.h5
# ./PredictModels/4_Fep_Xception_1.h5
# Probabilities for model 4_Fep_Xception_1.h5 (모낭홍반/농포):
# Class 0: 0.9256294928491116%
# Class 1: 23.778264224529266%
# Class 2: 60.76560616493225%
# Class 3: 14.530499279499054%
# [0.93, 23.78, 60.77, 14.53]
# 모델 파일: 4_Fep_Xception_1.h5
# 예측된 카테고리(모낭홍반/농포): 2
#
# c:\jupyter\capston\bald\hairskinWig
# 5_Dandruff_Xception_1.h5
# ./PredictModels/5_Dandruff_Xception_1.h5
# Probabilities for model 5_Dandruff_Xception_1.h5 (비듬):
# Class 0: 4.017006176582072e-05%
# Class 1: 0.034933394636027515%
# Class 2: 99.82671737670898%
# Class 3: 0.13831217074766755%
# [0.0, 0.03, 99.83, 0.14]
# 모델 파일: 5_Dandruff_Xception_1.h5
# 예측된 카테고리(비듬): 2
#
# c:\jupyter\capston\bald\hairskinWig
# 6_Hairloss_Xception_1.h5
# ./PredictModels/6_Hairloss_Xception_1.h5
# Probabilities for model 6_Hairloss_Xception_1.h5 (탈모):
# Class 0: 0.001613226777408272%
# Class 1: 3.07647455483675%
# Class 2: 1.7306812107563019%
# Class 3: 95.19124031066895%
# [0.0, 3.08, 1.73, 95.19]
# 모델 파일: 6_Hairloss_Xception_1.h5
# 예측된 카테고리(탈모): 3
#
# alter_predict:  ['3', '3', '3', '2', '2', '3']
#
# 복합성
# 3 3 3 2 2 3
# 0,0,0,100
# 0,0,0,100
# 0,1,2,96
# 1,24,61,15
# 0,0,100,0
# 0,3,2,95
# Mysql 전송 완료
# 192.168.43.1 - - [26/Nov/2023 20:27:23] "POST /upload HTTP/1.1" 200 -
# ['1_Corneous_Xception_1.h5', '2_Sebum_Xception_1.h5', '3_ErFo_Xception_1.h5', '4_Fep_Xception_1.h5', '5_Dandruff_Xception_1.h5', '6_Hairloss_Xception_1.h5']
# c:\jupyter\capston\bald\hairskinWig
# 1_Corneous_Xception_1.h5
# ./PredictModels/1_Corneous_Xception_1.h5
# Probabilities for model 1_Corneous_Xception_1.h5 (미세각질):
# Class 0: 1.8626552665719498e-11%
# Class 1: 2.319922565163779e-06%
# Class 2: 0.003968976670876145%
# Class 3: 99.99603033065796%
# [0.0, 0.0, 0.0, 100.0]
# 모델 파일: 1_Corneous_Xception_1.h5
# 예측된 카테고리(미세각질): 3
#
# c:\jupyter\capston\bald\hairskinWig
# 2_Sebum_Xception_1.h5
# ./PredictModels/2_Sebum_Xception_1.h5
# Probabilities for model 2_Sebum_Xception_1.h5 (피지과다):
# Class 0: 2.94764390673663e-05%
# Class 1: 99.94192123413086%
# Class 2: 0.035582733107730746%
# Class 3: 0.022471944976132363%
# [0.0, 99.94, 0.04, 0.02]
# 모델 파일: 2_Sebum_Xception_1.h5
# 예측된 카테고리(피지과다): 1
#
# c:\jupyter\capston\bald\hairskinWig
# 3_ErFo_Xception_1.h5
# ./PredictModels/3_ErFo_Xception_1.h5
# Probabilities for model 3_ErFo_Xception_1.h5 (모낭사이홍반):
# Class 0: 1.725885272026062%
# Class 1: 89.58812952041626%
# Class 2: 7.990718632936478%
# Class 3: 0.6952633615583181%
# [1.73, 89.59, 7.99, 0.7]
# 모델 파일: 3_ErFo_Xception_1.h5
# 예측된 카테고리(모낭사이홍반): 1
#
# c:\jupyter\capston\bald\hairskinWig
# 4_Fep_Xception_1.h5
# ./PredictModels/4_Fep_Xception_1.h5
# Probabilities for model 4_Fep_Xception_1.h5 (모낭홍반/농포):
# Class 0: 0.0014076948900765274%
# Class 1: 99.63558912277222%
# Class 2: 0.3256190801039338%
# Class 3: 0.03739152452908456%
# [0.0, 99.64, 0.33, 0.04]
# 모델 파일: 4_Fep_Xception_1.h5
# 예측된 카테고리(모낭홍반/농포): 1
#
# c:\jupyter\capston\bald\hairskinWig
# 5_Dandruff_Xception_1.h5
# ./PredictModels/5_Dandruff_Xception_1.h5
# Probabilities for model 5_Dandruff_Xception_1.h5 (비듬):
# Class 0: 6.566049787215533e-11%
# Class 1: 6.116584322368723e-09%
# Class 2: 0.0006504614248115104%
# Class 3: 99.99934434890747%
# [0.0, 0.0, 0.0, 100.0]
# 모델 파일: 5_Dandruff_Xception_1.h5
# 예측된 카테고리(비듬): 3
#
# c:\jupyter\capston\bald\hairskinWig
# 6_Hairloss_Xception_1.h5
# ./PredictModels/6_Hairloss_Xception_1.h5
# Probabilities for model 6_Hairloss_Xception_1.h5 (탈모):
# Class 0: 0.0004041373358631972%
# Class 1: 92.57190823554993%
# Class 2: 0.40135085582733154%
# Class 3: 7.026334851980209%
# [0.0, 92.57, 0.4, 7.03]
# 모델 파일: 6_Hairloss_Xception_1.h5
# 예측된 카테고리(탈모): 1
#
# alter_predict:  ['3', '1', '1', '1', '3', '1']
#
# 건성
# 3 1 1 1 3 1
# 0,0,0,100
# 0,100,0,0
# 2,90,8,1
# 0,100,0,0
# 0,0,0,100
# 0,93,0,7
# Mysql 전송 완료
# 192.168.43.1 - - [26/Nov/2023 20:27:54] "POST /upload HTTP/1.1" 200 -
# ['1_Corneous_Xception_1.h5', '2_Sebum_Xception_1.h5', '3_ErFo_Xception_1.h5', '4_Fep_Xception_1.h5', '5_Dandruff_Xception_1.h5', '6_Hairloss_Xception_1.h5']
# c:\jupyter\capston\bald\hairskinWig
# 1_Corneous_Xception_1.h5
# ./PredictModels/1_Corneous_Xception_1.h5
# Probabilities for model 1_Corneous_Xception_1.h5 (미세각질):
# Class 0: 99.9876618385315%
# Class 1: 0.012332151527516544%
# Class 2: 4.4478212224419167e-07%
# Class 3: 5.44045768435808e-06%
# [99.99, 0.01, 0.0, 0.0]
# 모델 파일: 1_Corneous_Xception_1.h5
# 예측된 카테고리(미세각질): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 2_Sebum_Xception_1.h5
# ./PredictModels/2_Sebum_Xception_1.h5
# Probabilities for model 2_Sebum_Xception_1.h5 (피지과다):
# Class 0: 100.0%
# Class 1: 4.898924643725877e-06%
# Class 2: 1.9487372826532123e-08%
# Class 3: 3.352671473777491e-08%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 2_Sebum_Xception_1.h5
# 예측된 카테고리(피지과다): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 3_ErFo_Xception_1.h5
# ./PredictModels/3_ErFo_Xception_1.h5
# Probabilities for model 3_ErFo_Xception_1.h5 (모낭사이홍반):
# Class 0: 99.99979734420776%
# Class 1: 0.0002070029040623922%
# Class 2: 3.5446237944825043e-06%
# Class 3: 1.3764753226119808e-10%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 3_ErFo_Xception_1.h5
# 예측된 카테고리(모낭사이홍반): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 4_Fep_Xception_1.h5
# ./PredictModels/4_Fep_Xception_1.h5
# Probabilities for model 4_Fep_Xception_1.h5 (모낭홍반/농포):
# Class 0: 100.0%
# Class 1: 1.1244482775452092e-09%
# Class 2: 2.012144006968697e-07%
# Class 3: 4.474856249436776e-09%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 4_Fep_Xception_1.h5
# 예측된 카테고리(모낭홍반/농포): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 5_Dandruff_Xception_1.h5
# ./PredictModels/5_Dandruff_Xception_1.h5
# Probabilities for model 5_Dandruff_Xception_1.h5 (비듬):
# Class 0: 100.0%
# Class 1: 6.031629189162668e-11%
# Class 2: 1.6846779115440067e-16%
# Class 3: 5.679052336055277e-16%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 5_Dandruff_Xception_1.h5
# 예측된 카테고리(비듬): 0
#
# c:\jupyter\capston\bald\hairskinWig
# 6_Hairloss_Xception_1.h5
# ./PredictModels/6_Hairloss_Xception_1.h5
# Probabilities for model 6_Hairloss_Xception_1.h5 (탈모):
# Class 0: 99.99991655349731%
# Class 1: 8.172525554073218e-05%
# Class 2: 1.6604267960573793e-07%
# Class 3: 1.1222411194777848e-08%
# [100.0, 0.0, 0.0, 0.0]
# 모델 파일: 6_Hairloss_Xception_1.h5
# 예측된 카테고리(탈모): 0
#
# alter_predict:  ['0', '0', '0', '0', '0', '0']
#
# 양호
# 0 0 0 0 0 0
# 100,0,0,0
# 100,0,0,0
# 100,0,0,0
# 100,0,0,0
# 100,0,0,0
# 100,0,0,0
# Mysql 전송 완료
# 192.168.43.1 - - [26/Nov/2023 20:30:43] "POST /upload HTTP/1.1" 200 -
# 받은 증상: 양호
# ['양호']
# {}
# 받은 증상: 양호
# ['양호']
# {}
# 192.168.43.1 - - [26/Nov/2023 20:31:07] "GET /beauty_supplies?symptom=양호 HTTP/1.1" 200 -
# 192.168.43.1 - - [26/Nov/2023 20:31:08] "GET /beauty_supplies?symptom=양호 HTTP/1.1" 200 -
# Image 1 added to the ZIP archive
# Image 2 added to the ZIP archive
# Image 3 added to the ZIP archive
# Image 4 added to the ZIP archive
# Image 5 added to the ZIP archive
# ZIP file saved to ./get_analysis_data/image_data.zip
# ./get_analysis_data/image_data.zip
# image_data.zip
# 192.168.43.1 - - [26/Nov/2023 20:32:37] "GET /progress_status?userId=mingky0603 HTTP/1.1" 200 -
# True
# 전처리 완료
# c:\jupyter\capston\bald\hairskinWig\face_align.py:392: FutureWarning: `multichannel` is a deprecated argument name for `gaussian`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   small_blurred = gaussian(cv2.resize(img, (W, H)), H//100, multichannel=True)
# 192.168.43.1 - - [26/Nov/2023 20:34:38] "POST /wear_wig HTTP/1.1" 200 -
